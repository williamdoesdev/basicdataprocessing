# %%
import os
import pandas
import io

# %%
f = open('datalake/layer=bronze/table=header/year=2018/ams__header_2018__202001290000-002.csv', 'r')
text = ''.join(f.readlines(4096))
csv_string_io = io.StringIO(text)
df = pandas.read_csv(csv_string_io)
df
# df.columns.values.tolist()
# Out:
#     identifier carrier_code vessel_country_code vessel_name  \
# 0    201801010         DFDS                  GB  EVER SIGMA
# 1    201801011         DFDS                  GB  EVER SIGMA
# 2    201801012         DFDS                  GB  EVER SIGMA
# 3    201801013         DFDS                  GB  EVER SIGMA
# 4    201801014         DFDS                  GB  EVER SIGMA
# 5    201801015         DFDS                  GB  EVER SIGMA
# 6    201801016         DFDS                  GB  EVER SIGMA
# 7    201801017         DFDS                  GB  EVER SIGMA
# 8    201801018         DFDS                  GB  EVER SIGMA
# 9    201801019         DFDS                  GB  EVER SIGMA
# 10  2018010110         DFDS                  GB  EVER SIGMA
# 11  2018010111         DFDS                  GB  EVER SIGMA
# 12  2018010112         DFDS                  GB  EVER SIGMA
# 13  2018010113         DFDS                  GB  EVER SIGMA
#
#            port_of_unlading estimated_arrival_date  \
# ...
